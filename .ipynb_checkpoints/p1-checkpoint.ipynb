# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
#extract information from wikipedia
#get information about top 100
linkk='https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_'

rate=[]
song=[]
artist=[]
year=[]


for j in range(1980,2022,1): #use for loop to extract
    
    try:
    
        
        
        page = requests.get(linkk+str(j)) #request data for above link

        soup = BeautifulSoup(page.content, 'html.parser')
        #print(soup)
        tds=soup.find_all('td')


        for i in range(0,300,3):
            rate.append(int(tds[i].text))


        for i in range(1,300,3):
            song.append(tds[i].text.replace('"',''))


        for i in range(2,300,3):
            artist.append(tds[i].text.replace("\n",''))
            year.append(j) 
        
        print(j)
    except:
        
        
        page = requests.get(linkk+str(j)) #request data for above link

        soup = BeautifulSoup(page.content, 'html.parser')
        #print(soup)
        tds=soup.find_all('td')


        for i in range(2,302,3):
            rate.append(int(tds[i].text))

        for i in range(3,302,3):
            song.append(tds[i].text.replace('"',''))


        for i in range(4,302,3):
            artist.append(tds[i].text.replace("\n",''))
            year.append(j)
        print(j)
# Out:
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021

# %%
data={'rating':rate,'song_name':song, 'artist':artist,'year':year}

df=pd.DataFrame(data)

# %%
df
# Out:
#       rating                           song_name  \
# 0          1                             Call Me
# 1          2  Another Brick in the Wall, Part II
# 2          3                               Magic
# 3          4                       Rock with You
# 4          5         Do That to Me One More Time
# ...      ...                                 ...
# 4195      96            Things a Man Oughta Know
# 4196      97               Throat Baby (Go Baby)
# 4197      98                           Tombstone
# 4198      99   Drinkin' Beer. Talkin' God. Amen.
# 4199     100                          Todo de Ti
#
#                                          artist  year
# 0                                       Blondie  1980
# 1                                    Pink Floyd  1980
# 2                            Olivia Newton-John  1980
# 3                               Michael Jackson  1980
# 4                            Captain & Tennille  1980
# ...
